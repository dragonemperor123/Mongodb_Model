# %%
import pandas as pd

# %%
df = pd.read_csv("adult_data.csv")

# %%
df
# Out:
#        Age          Workclass  fnlwgt    Education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          Occupation    Relationship    Race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.isnull().any()
# Out:
# Age               False
# Workclass         False
# fnlwgt            False
# Education         False
# education-num     False
# marital-status    False
# Occupation        False
# Relationship      False
# Race              False
# Sex               False
# Capital-Gain      False
# Capital-Loss      False
# Hours-per-week    False
# native-country    False
# Income            False
# dtype: bool

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.describe().T
# Out:
#                   count           mean            std      min       25%  \
# Age             32561.0      38.581647      13.640433     17.0      28.0
# fnlwgt          32561.0  189778.366512  105549.977697  12285.0  117827.0
# education-num   32561.0      10.080679       2.572720      1.0       9.0
# Capital-Gain    32561.0    1077.648844    7385.292085      0.0       0.0
# Capital-Loss    32561.0      87.303830     402.960219      0.0       0.0
# Hours-per-week  32561.0      40.437456      12.347429      1.0      40.0
#
#                      50%       75%        max
# Age                 37.0      48.0       90.0
# fnlwgt          178356.0  237051.0  1484705.0
# education-num       10.0      12.0       16.0
# Capital-Gain         0.0       0.0    99999.0
# Capital-Loss         0.0       0.0     4356.0
# Hours-per-week      40.0      45.0       99.0

# %%
df.info
# Out:
# <bound method DataFrame.info of        Age          Workclass  fnlwgt    Education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          Occupation    Relationship    Race  \
# ...

# %%
df.dtypes
# Out:
# Age                int64
# Workclass         object
# fnlwgt             int64
# Education         object
# education-num      int64
# marital-status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Capital-Gain       int64
# Capital-Loss       int64
# Hours-per-week     int64
# native-country    object
# Income            object
# dtype: object

# %%
categorical= [fea for fea in df.columns if df[fea].dtype == 'O']

# %%
numerical= [fea for fea in df.columns if df[fea].dtype != 'O']

# %%
categorical
# Out:
# ['Workclass',
#  'Education',
#  'marital-status',
#  'Occupation',
#  'Relationship',
#  'Race',
#  'Sex',
#  'native-country',
#  'Income']

# %%
numerical
# Out:
# ['Age',
#  'fnlwgt',
#  'education-num',
#  'Capital-Gain',
#  'Capital-Loss',
#  'Hours-per-week']

# %%
df.nunique
# Out:
# <bound method DataFrame.nunique of        Age          Workclass  fnlwgt    Education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          Occupation    Relationship    Race  \
# ...

# %%
df.corr()
# Out:
#                      Age    fnlwgt  education-num  Capital-Gain  Capital-Loss  \
# Age             1.000000 -0.076646       0.036527      0.077674      0.057775
# fnlwgt         -0.076646  1.000000      -0.043195      0.000432     -0.010252
# education-num   0.036527 -0.043195       1.000000      0.122630      0.079923
# Capital-Gain    0.077674  0.000432       0.122630      1.000000     -0.031615
# Capital-Loss    0.057775 -0.010252       0.079923     -0.031615      1.000000
# Hours-per-week  0.068756 -0.018768       0.148123      0.078409      0.054256
#
#                 Hours-per-week
# Age                   0.068756
# fnlwgt               -0.018768
# education-num         0.148123
# Capital-Gain          0.078409
# Capital-Loss          0.054256
# Hours-per-week        1.000000

# %%
df.skew()
# Out:
# Age                0.558743
# fnlwgt             1.446980
# education-num     -0.311676
# Capital-Gain      11.953848
# Capital-Loss       4.594629
# Hours-per-week     0.227643
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)

for i in range(0, len(numerical)):
    plt.subplot(5, 3, i+1)
    sns.kdeplot(x=df[numerical[i]],shade=True, color='b')
    plt.xlabel(numerical[i])
    plt.tight_layout()

# %%
plt.figure(figsize = (15,10))
sns.heatmap(df.corr(), cmap="CMRmap", annot=True)
plt.show()

# %%
fig = plt.figure(figsize = (15,10))

ax1 = fig.add_subplot(2,3,1)
sns.countplot(data = df, x = 'Workclass', ax=ax1)
ax1.set_xticklabels(ax1.get_xticks(), rotation = 45)

ax2 = fig.add_subplot(2,3,2)
sns.countplot(data = df, x = 'Education', ax=ax2)
ax2.set_xticklabels(ax2.get_xticks(), rotation = 45)

ax3 = fig.add_subplot(2,3,3)
sns.countplot(data = df, x = 'marital-status', ax=ax3)
ax3.set_xticklabels(ax3.get_xticks(), rotation = 45)

#ax4 = fig.add_subplot(2,3,4)
#sns.boxplot(data = df, x = 'Workclass', y = 'Education' , ax=ax4)
#sns.violinplot(data = ds_cat, x = 'MSZoning', y = 'SalePrice' , ax=ax4)
#sns.swarmplot(data = ds_cat, x = 'MSZoning', y='SalePrice', color = 'k', alpha = 0.4, ax=ax4  )

#ax5 = fig.add_subplot(2,3,5)
#sns.boxplot(data = df, x = 'marital-status', y = 'Education', ax=ax5)
#sns.violinplot(data = ds_cat, x = 'LotShape', y = 'SalePrice', ax=ax5)
#sns.swarmplot(data = ds_cat, x = 'LotShape', y='SalePrice', color = 'k', alpha = 0.4, ax=ax5  )

#ax6 = fig.add_subplot(2,3,6)
#sns.boxplot(data = df, x = 'Income', y = 'Education', ax=ax6)
#sns.violinplot(data = ds_cat, x = 'LotConfig', y = 'SalePrice', ax=ax6)
#sns.swarmplot(data = ds_cat, x = 'LotConfig', y='SalePrice', color = 'k', alpha = 0.4, ax=ax6  )
# Out:
# [Text(0, 0, '0'),
#  Text(1, 0, '1'),
#  Text(2, 0, '2'),
#  Text(3, 0, '3'),
#  Text(4, 0, '4'),
#  Text(5, 0, '5'),
#  Text(6, 0, '6')]

# %%
#X=df.drop("Income",axis=1)

# %%
#X

# %%
#Y=df["Income"]

# %%
#Y

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df['Workclass'] = encoder.fit_transform(df['Workclass'])

# %%
df['Workclass']
# Out:
# 0        7
# 1        6
# 2        4
# 3        4
# 4        4
#         ..
# 32556    4
# 32557    4
# 32558    4
# 32559    4
# 32560    5
# Name: Workclass, Length: 32561, dtype: int32

# %%
numeric_features = [feature for feature in df.columns if df[feature].dtype != 'O']
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']

# %%
categorical_features
# Out:
# ['Education',
#  'marital-status',
#  'Occupation',
#  'Relationship',
#  'Race',
#  'Sex',
#  'native-country',
#  'Income']

# %%
df['Education'] = encoder.fit_transform(df['Education'])

# %%
df['marital-status'] = encoder.fit_transform(df['marital-status'])

# %%
df['Occupation'] = encoder.fit_transform(df['Occupation'])

# %%
df['Relationship'] = encoder.fit_transform(df['Relationship'])

# %%
df['Race'] = encoder.fit_transform(df['Race'])

# %%
df['Sex'] = encoder.fit_transform(df['Sex'])

# %%
df['native-country'] = encoder.fit_transform(df['native-country'])

# %%
df['Income'] = encoder.fit_transform(df['Income'])

# %%
df
# Out:
#        Age  Workclass  fnlwgt  Education  education-num  marital-status  \
# 0       39          7   77516          9             13               4
# 1       50          6   83311          9             13               2
# 2       38          4  215646         11              9               0
# 3       53          4  234721          1              7               2
# 4       28          4  338409          9             13               2
# ...    ...        ...     ...        ...            ...             ...
# 32556   27          4  257302          7             12               2
# 32557   40          4  154374         11              9               2
# 32558   58          4  151910         11              9               6
# 32559   22          4  201490         11              9               4
# 32560   52          5  287927         11              9               2
#
#        Occupation  Relationship  Race  Sex  Capital-Gain  Capital-Loss  \
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
scaler.fit(df)
StandardScaler()
print(scaler.mean_)
# Out:
# [3.85816468e+01 3.86889223e+00 1.89778367e+05 1.02982095e+01
#  1.00806793e+01 2.61183625e+00 6.57274039e+00 1.44636221e+00
#  3.66585793e+00 6.69205491e-01 1.07764884e+03 8.73038297e+01
#  4.04374559e+01 3.67188661e+01 2.40809557e-01]

# %%
data_tr=scaler.transform(df)

# %%
df
# Out:
#        Age  Workclass  fnlwgt  Education  education-num  marital-status  \
# 0       39          7   77516          9             13               4
# 1       50          6   83311          9             13               2
# 2       38          4  215646         11              9               0
# 3       53          4  234721          1              7               2
# 4       28          4  338409          9             13               2
# ...    ...        ...     ...        ...            ...             ...
# 32556   27          4  257302          7             12               2
# 32557   40          4  154374         11              9               2
# 32558   58          4  151910         11              9               6
# 32559   22          4  201490         11              9               4
# 32560   52          5  287927         11              9               2
#
#        Occupation  Relationship  Race  Sex  Capital-Gain  Capital-Loss  \
# ...

# %%
data_tra = pd.DataFrame(data_tr,columns = ["Age","Workclass","fnlwgt","Education","education-num","marital-status","Occupation","Relationship","Race","Sex","Capital-Gain","Capital-Loss","Hours-per-week","native-country","Income"])

# %%
data_tra
# Out:
#             Age  Workclass    fnlwgt  Education  education-num  \
# 0      0.030671   2.150579 -1.063611  -0.335437       1.134739
# 1      0.837109   1.463736 -1.008707  -0.335437       1.134739
# 2     -0.042642   0.090050  0.245079   0.181332      -0.420060
# 3      1.057047   0.090050  0.425801  -2.402511      -1.197459
# 4     -0.775768   0.090050  1.408176  -0.335437       1.134739
# ...         ...        ...       ...        ...            ...
# 32556 -0.849080   0.090050  0.639741  -0.852205       0.746039
# 32557  0.103983   0.090050 -0.335433   0.181332      -0.420060
# 32558  1.423610   0.090050 -0.358777   0.181332      -0.420060
# 32559 -1.215643   0.090050  0.110960   0.181332      -0.420060
# 32560  0.983734   0.776893  0.929893   0.181332      -0.420060
#
#        marital-status  Occupation  Relationship      Race       Sex  \
# 0            0.921634   -1.317809     -0.277805  0.393668  0.703071
# 1           -0.406212   -0.608387     -0.900181  0.393668  0.703071
# ...

# %%
X=data_tra.drop("Income",axis=1)

# %%
Y=df["Income"]

# %%
X
# Out:
#             Age  Workclass    fnlwgt  Education  education-num  \
# 0      0.030671   2.150579 -1.063611  -0.335437       1.134739
# 1      0.837109   1.463736 -1.008707  -0.335437       1.134739
# 2     -0.042642   0.090050  0.245079   0.181332      -0.420060
# 3      1.057047   0.090050  0.425801  -2.402511      -1.197459
# 4     -0.775768   0.090050  1.408176  -0.335437       1.134739
# ...         ...        ...       ...        ...            ...
# 32556 -0.849080   0.090050  0.639741  -0.852205       0.746039
# 32557  0.103983   0.090050 -0.335433   0.181332      -0.420060
# 32558  1.423610   0.090050 -0.358777   0.181332      -0.420060
# 32559 -1.215643   0.090050  0.110960   0.181332      -0.420060
# 32560  0.983734   0.776893  0.929893   0.181332      -0.420060
#
#        marital-status  Occupation  Relationship      Race       Sex  \
# 0            0.921634   -1.317809     -0.277805  0.393668  0.703071
# 1           -0.406212   -0.608387     -0.900181  0.393668  0.703071
# ...

# %%
Y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32556    0
# 32557    1
# 32558    0
# 32559    0
# 32560    1
# Name: Income, Length: 32561, dtype: int32

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(
 X, Y, test_size=0.33, random_state=42)

# %%
X_train
# Out:
#             Age  Workclass    fnlwgt  Education  education-num  \
# 27585  0.910422   0.090050 -0.628616   0.439716       1.523438
# 18010  0.543859  -2.657320 -0.391189   0.181332      -0.420060
# 22472 -0.995706   0.090050  0.735707  -0.335437       1.134739
# 4585  -0.849080   0.090050 -1.446639  -0.852205       0.746039
# 11191  0.617171  -1.283635 -0.713601   0.439716       1.523438
# ...         ...        ...       ...        ...            ...
# 29802  0.617171   0.090050  1.607629  -0.335437       1.134739
# 5390  -0.555830   0.090050 -0.403259  -2.144127      -0.808759
# 860   -1.508894   0.090050  0.251123  -2.402511      -1.197459
# 15795  0.837109   1.463736 -1.283936   0.181332      -0.420060
# 23654 -0.335892   0.776893 -0.588615  -0.335437       1.134739
#
#        marital-status  Occupation  Relationship      Race       Sex  \
# 27585       -0.406212   -0.608387     -0.900181  0.393668  0.703071
# 18010        0.257711   -1.554283     -0.277805 -3.140765  0.703071
# ...

# %%
Y_train
# Out:
# 27585    1
# 18010    0
# 22472    0
# 4585     0
# 11191    1
#         ..
# 29802    0
# 5390     0
# 860      0
# 15795    0
# 23654    0
# Name: Income, Length: 21815, dtype: int32

# %%
import pickle
pickle.dump(data_tr, open('model.pkl','wb'))

# %%
import pymongo
from pymongo import MongoClient

# %%
client = pymongo.MongoClient("mongodb+srv://Adwait:Darkmatter!1@cluster0.g1q8onc.mongodb.net/?retryWrites=true&w=majority")
db = client.test

# %%
#myclient = pymongo.MongoClient(MONGO_HOST, MONGO_PORT)
#mydb = myclient[MONGO_DB]
#mycol = mydb['mycollection']

# %%
#with open(model_file, "rb") as f:
 #   encoded = Binary(f.read())
#mycol.insert_one({"filename": model_file, "file": encoded, "description": "Preprocessing model" })

# %%
from bson.binary import Binary
from bson import ObjectId
import pymongo, gridfs
from gridfs import GridFS
from pymongo import MongoClient

MONGO_HOST = "127.0.0.1"
MONGO_PORT = 27017
MONGO_DB = "FirstDB"

model_file = 'model.pkl'

myclient = pymongo.MongoClient("mongodb+srv://Adwait:Darkmatter!1@cluster0.g1q8onc.mongodb.net/?retryWrites=true&w=majority")
mydb = myclient[MONGO_DB]
mycol = mydb['Addy']

# Store model as binary document
with open(model_file, "rb") as f:
    encoded = Binary(f.read())
mycol.insert_one({"filename": model_file, "file": encoded, "description": "Keras model" })

# Retrieve and store the ML model from MongoDB
data = mycol.find_one({'filename': 'model.pkl'})
with open("keras_model_fromMongo.h5", "wb") as f:
    f.write(data['file'])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report


logreg = LogisticRegression()

# Fit the classifier to the training data
logreg.fit(X_train, Y_train)

# Predict the labels of the test set: y_pred
y_pred = logreg.predict(X_test)

# Compute and print the confusion matrix and classification report
print(confusion_matrix(Y_test, y_pred))
print(classification_report(Y_test, y_pred))
# Out:
# [[7738  458]
#  [1408 1142]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.94      0.89      8196
#            1       0.71      0.45      0.55      2550
#
#     accuracy                           0.83     10746
#    macro avg       0.78      0.70      0.72     10746
# weighted avg       0.81      0.83      0.81     10746

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.svm import SVC
svclassifier = SVC(kernel='poly', degree=8)
svclassifier.fit(X_train, Y_train)
# Out:
# SVC(degree=8, kernel='poly')

# %%
y_pred = svclassifier.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])
